# %%
import pandas as pan
import matplotlib.pyplot as plot

# %%
# Load data
data = pan.read_table('result.data', sep=r"\s+", header=0)

# %%
data['type'] = data.type.apply(lambda x: x.strip())
data2 = data.groupby(['n', 'type']).agg({'time': 'mean'})
data3 = data2.unstack('type')
data3.columns = data3.columns.get_level_values(1)
data3
# Out:
# type        basic  basic_o2      both   both_o2   builtin  builtin_o2  \
# n
# 9.0      0.000002  0.000002  0.000002  0.000002  0.000003    0.000002
# 16.0     0.000002  0.000002  0.000002  0.000002  0.000003    0.000002
# 25.0     0.000003  0.000002  0.000003  0.000003  0.000004    0.000003
# 36.0     0.000005  0.000002  0.000003  0.000006  0.000004    0.000003
# 49.0     0.000005  0.000003  0.000005  0.000002  0.000006    0.000003
# 64.0     0.000007  0.000002  0.000006  0.000003  0.000008    0.000003
# 81.0     0.000009  0.000003  0.000007  0.000003  0.000010    0.000003
# 100.0    0.000012  0.000003  0.000009  0.000003  0.000013    0.000003
# 121.0    0.000015  0.000003  0.000011  0.000003  0.000017    0.000003
# 144.0    0.000019  0.000004  0.000013  0.000004  0.000021    0.000004
# 169.0    0.000023  0.000005  0.000017  0.000004  0.000025    0.000005
# 196.0    0.000030  0.000006  0.000020  0.000005  0.000031    0.000006
# ...

# %%
data3.plot(figsize=(10,15), loglog=True)
plot.savefig("graph.png")
plot.show()
# Out:
# /usr/lib/python3/dist-packages/matplotlib/scale.py:101: RuntimeWarning: invalid value encountered in less_equal
#   a[a <= 0.0] = 1e-300
